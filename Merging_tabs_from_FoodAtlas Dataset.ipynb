# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
# import Health and Physical Activity data.
health = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='HEALTH')
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS                   3143 non-null   int64
#  1   State                  3143 non-null   object
#  2   County                 3143 non-null   object
#  3   PCT_DIABETES_ADULTS09  3138 non-null   float64
#  4   PCT_DIABETES_ADULTS10  3138 non-null   float64
#  5   PCT_OBESE_ADULTS09     3138 non-null   float64
#  6   PCT_OBESE_ADULTS10     3138 non-null   float64
#  7   PCT_OBESE_ADULTS13     3138 non-null   float64
#  8   PCT_OBESE_CHILD08      2691 non-null   float64
#  9   PCT_OBESE_CHILD11      2714 non-null   float64
#  10  PCH_OBESE_CHILD_08_11  2636 non-null   float64
#  11  PCT_HSPA09             2503 non-null   float64
#  12  RECFAC07               3138 non-null   float64
#  13  RECFAC12               3138 non-null   float64
#  14  PCH_RECFAC_07_12       3014 non-null   float64
#  15  RECFACPTH07            3138 non-null   float64
#  16  RECFACPTH12            3138 non-null   float64
#  17  PCH_RECFACPTH_07_12    3014 non-null   float64
#  18  NATAMEN                3108 non-null   float64
# dtypes: float64(16), int64(1), object(2)
# memory usage: 466.7+ KB

# %%
# get variable that we'll be solving for: "Adult obesity rate by county in 2010" [PCT_OBESE_ADULTS10]
obesity = health[['FIPS','State','County','PCT_OBESE_ADULTS10']]

# %%
obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FIPS                3143 non-null   int64
#  1   State               3143 non-null   object
#  2   County              3143 non-null   object
#  3   PCT_OBESE_ADULTS10  3138 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 98.3+ KB

# %%
# get health variables 
# future data (after 2010 will NOT be included)
# obesity rates for previous years and diabetes rates will NOT be included
# [PCT_HSPA09] feature has too many NULLs
health=health[['FIPS','State','County','RECFACPTH07','NATAMEN']]
health.drop('FIPS',axis=1).corr()
# Out:
#              RECFACPTH07   NATAMEN
# RECFACPTH07     1.000000  0.039909
# NATAMEN         0.039909  1.000000

# %%
# import Access and Proximity to Grocery Store data 
access = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='ACCESS')
access.describe()
# Out:
#                FIPS  LACCESS_POP10  PCT_LACCESS_POP10  LACCESS_LOWI10  \
# count   3256.000000    3144.000000        3144.000000     3144.000000
# mean   31500.533170   20152.907844          23.556606     5550.238428
# std    16359.620487   51301.132595          20.247530    13860.985712
# min     1001.000000       0.000000           0.000000        0.000000
# 25%    19034.500000    1663.525757          10.851679      593.104104
# 50%    30044.000000    4100.752043          19.682744     1500.408081
# 75%    47009.500000   12952.524765          29.580035     4590.737731
# max    72153.000000  886068.668386         100.000001   292541.789025
#
#        PCT_LACCESS_LOWI10  LACCESS_CHILD10  PCT_LACCESS_CHILD10  \
# count         3144.000000      3144.000000          3144.000000
# mean             8.372697      4958.430228             5.504971
# std              8.214656     13167.281455             4.879689
# min              0.000000         0.000000             0.000000
# 25%              3.441106       365.182063             2.399471
# 50%              6.150399       939.088775             4.443521
# 75%             10.323625      3007.985909             6.962248
# max             72.274456    260308.794094            34.015595
#
#        LACCESS_SENIORS10  PCT_LACCESS_SENIORS10  LACCESS_HHNV10  \
# count        3144.000000            3144.000000     3144.000000
# mean         2681.564154               3.914636      660.594287
# std          6525.650136               4.214783     1121.014860
# min             0.000000               0.000000        0.000000
# 25%           276.537225               1.584069      118.022546
# 50%           676.612645               2.826430      320.013520
# 75%          1862.566665               4.519518      706.477808
# max         78922.918719              29.208633    16334.423176
#
#        PCT_LACCESS_HHNV10
# count         3144.000000
# mean             3.153581
# std              3.207006
# min              0.000000
# 25%              1.609068
# 50%              2.571179
# 75%              3.804970
# max             68.470405

# %%
# drop freatures that show abs number, keep percent pop features
access.drop(['LACCESS_POP10','LACCESS_LOWI10','LACCESS_CHILD10','LACCESS_SENIORS10','LACCESS_HHNV10'],axis=1,inplace=True)

# %%
access.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3256 entries, 0 to 3255
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS                   3256 non-null   int64
#  1   State                  3256 non-null   object
#  2   County                 3256 non-null   object
#  3   PCT_LACCESS_POP10      3144 non-null   float64
#  4   PCT_LACCESS_LOWI10     3144 non-null   float64
#  5   PCT_LACCESS_CHILD10    3144 non-null   float64
#  6   PCT_LACCESS_SENIORS10  3144 non-null   float64
#  7   PCT_LACCESS_HHNV10     3144 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 203.6+ KB

# %%
# check correlation of access features
access.drop('FIPS',axis=1).corr()
# Out:
#                        PCT_LACCESS_POP10  PCT_LACCESS_LOWI10  \
# PCT_LACCESS_POP10               1.000000            0.901974
# PCT_LACCESS_LOWI10              0.901974            1.000000
# PCT_LACCESS_CHILD10             0.960289            0.890368
# PCT_LACCESS_SENIORS10           0.919664            0.826814
# PCT_LACCESS_HHNV10              0.120455            0.278831
#
#                        PCT_LACCESS_CHILD10  PCT_LACCESS_SENIORS10  \
# PCT_LACCESS_POP10                 0.960289               0.919664
# PCT_LACCESS_LOWI10                0.890368               0.826814
# PCT_LACCESS_CHILD10               1.000000               0.823559
# PCT_LACCESS_SENIORS10             0.823559               1.000000
# PCT_LACCESS_HHNV10                0.162754               0.043646
#
#                        PCT_LACCESS_HHNV10
# PCT_LACCESS_POP10                0.120455
# PCT_LACCESS_LOWI10               0.278831
# PCT_LACCESS_CHILD10              0.162754
# PCT_LACCESS_SENIORS10            0.043646
# PCT_LACCESS_HHNV10               1.000000

# %% [markdown]
# All features in 'access' are highly correlated with the exception of [PCT_LACCESS_HHNV10]

# %%
# import Store Availability data 
stores = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='STORES')
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FIPS                 3221 non-null   int64
#  1   State                3221 non-null   object
#  2   County               3143 non-null   object
#  3   GROC07               3143 non-null   float64
#  4   GROC12               3143 non-null   float64
#  5   PCH_GROC_07_12       3116 non-null   float64
#  6   GROCPTH07            3143 non-null   float64
#  7   GROCPTH12            3143 non-null   float64
#  8   PCH_GROCPTH_07_12    3121 non-null   float64
#  9   SUPERC07             3143 non-null   float64
#  10  SUPERC12             3143 non-null   float64
#  11  PCH_SUPERC_07_12     2638 non-null   float64
#  12  SUPERCPTH07          3143 non-null   float64
#  13  SUPERCPTH12          3143 non-null   float64
#  14  PCH_SUPERCPTH_07_12  2638 non-null   float64
#  15  CONVS07              3143 non-null   float64
#  16  CONVS12              3143 non-null   float64
#  17  PCH_CONVS_07_12      3118 non-null   float64
#  18  CONVSPTH07           3143 non-null   float64
#  19  CONVSPTH12           3143 non-null   float64
#  20  PCH_CONVSPTH_07_12   3122 non-null   float64
#  21  SPECS07              3143 non-null   float64
#  22  SPECS12              3143 non-null   float64
#  23  PCH_SPECS_07_12      2970 non-null   float64
#  24  SPECSPTH07           3143 non-null   float64
#  25  SPECSPTH12           3143 non-null   float64
#  26  PCH_SPECSPTH_07_12   2974 non-null   float64
#  27  SNAPS08              3143 non-null   float64
#  28  SNAPS12              3143 non-null   float64
#  29  PCH_SNAPS_08_12      3138 non-null   float64
#  30  SNAPSPTH08           3143 non-null   float64
#  31  SNAPSPTH12           3143 non-null   float64
#  32  PCH_SNAPSPTH_08_12   3138 non-null   float64
#  33  WICS08               3143 non-null   float64
#  34  WICS12               3143 non-null   float64
#  35  PCH_WICS_08_12       3124 non-null   float64
#  36  WICSPTH08            3143 non-null   float64
#  37  WICSPTH12            3143 non-null   float64
#  38  PCH_WICSPTH_08_12    3124 non-null   float64
# dtypes: float64(36), int64(1), object(2)
# memory usage: 981.5+ KB

# %%
# drop columns with data for 2012. It's considered to be 'future data' 
# because our dependent variable data (obesity rate) is for 2010
col_list = [col for col in stores.columns if '12' in col]
stores.drop(col_list, axis=1, inplace=True)

# %%
# drop columns that contain absolute values. We can remove them since we have # per 1,000 pop columns that describe
# the same feature (e.g. "Grocery stores, 2007" vs "Grocery stores/1,000 pop, 2007")
stores.drop(['GROC07','SUPERC07','CONVS07','SPECS07','SNAPS08','WICS08'],axis=1,inplace=True)

# %%
# check feature correlation 
# FIPS (State and county Federal information processing standards) doesn't need to be included
stores.drop('FIPS',axis=1).corr()
# Out:
#              GROCPTH07  SUPERCPTH07  CONVSPTH07  SPECSPTH07  SNAPSPTH08  \
# GROCPTH07     1.000000    -0.168760    0.329326    0.058279    0.459007
# SUPERCPTH07  -0.168760     1.000000   -0.029152    0.001738   -0.053056
# CONVSPTH07    0.329326    -0.029152    1.000000    0.284741    0.033836
# SPECSPTH07    0.058279     0.001738    0.284741    1.000000   -0.116132
# SNAPSPTH08    0.459007    -0.053056    0.033836   -0.116132    1.000000
# WICSPTH08     0.637915    -0.137765    0.210178   -0.025520    0.547786
#
#              WICSPTH08
# GROCPTH07     0.637915
# SUPERCPTH07  -0.137765
# CONVSPTH07    0.210178
# SPECSPTH07   -0.025520
# SNAPSPTH08    0.547786
# WICSPTH08     1.000000

# %%
# import Restaurant Availability and Expenditures data
rstrnt = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='RESTAURANTS')
rstrnt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FIPS              3143 non-null   int64
#  1   State             3143 non-null   object
#  2   County            3143 non-null   object
#  3   FFR07             3138 non-null   float64
#  4   FFR12             3143 non-null   int64
#  5   PCH_FFR_07_12     3100 non-null   float64
#  6   FFRPTH07          3138 non-null   float64
#  7   FFRPTH12          3143 non-null   float64
#  8   PCH_FFRPTH_07_12  3143 non-null   float64
#  9   FSR07             3138 non-null   float64
#  10  FSR12             3143 non-null   int64
#  11  PCH_FSR_07_12     3115 non-null   float64
#  12  FSRPTH07          3138 non-null   float64
#  13  FSRPTH12          3143 non-null   float64
#  14  PCH_FSRPTH_07_12  3143 non-null   float64
#  15  PC_FFRSALES02     3127 non-null   float64
#  16  PC_FFRSALES07     3143 non-null   float64
#  17  PC_FSRSALES02     3127 non-null   float64
#  18  PC_FSRSALES07     3143 non-null   float64
# dtypes: float64(14), int64(3), object(2)
# memory usage: 466.7+ KB

# %%
# drop columns with data for 2012
# drop columns that contain absolute values and keep # per 1,000 pop columns
# drop columns that contain data for 2002: there are columns describing the same features for 2007
col_list = [col for col in rstrnt.columns if '12' in col]
rstrnt.drop(col_list, axis=1, inplace=True)
rstrnt.drop(['FFR07','FSR07','PC_FFRSALES02','PC_FSRSALES02'], axis=1, inplace=True)
rstrnt.drop('FIPS',axis=1).corr()
# Out:
#                FFRPTH07  FSRPTH07  PC_FFRSALES07  PC_FSRSALES07
# FFRPTH07       1.000000  0.346550       0.095094       0.114840
# FSRPTH07       0.346550  1.000000      -0.091651       0.135890
# PC_FFRSALES07  0.095094 -0.091651       1.000000       0.498603
# PC_FSRSALES07  0.114840  0.135890       0.498603       1.000000

# %%
# import Food Assistance data
assist = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='ASSISTANCE')
assist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 55 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FIPS                     3143 non-null   int64
#  1   State                    3143 non-null   object
#  2   County                   3143 non-null   object
#  3   REDEMP_SNAPS08           2815 non-null   float64
#  4   REDEMP_SNAPS12           2901 non-null   float64
#  5   PCH_REDEMP_SNAPS_08_12   2801 non-null   float64
#  6   PCT_SNAP09               3143 non-null   float64
#  7   PCT_SNAP14               3143 non-null   float64
#  8   PCH_SNAP_09_14           3143 non-null   float64
#  9   PC_SNAPBEN08             3132 non-null   float64
#  10  PC_SNAPBEN10             2753 non-null   float64
#  11  PCH_PC_SNAPBEN_08_10     2752 non-null   float64
#  12  SNAP_PART_RATE08         3143 non-null   float64
#  13  SNAP_PART_RATE10         3143 non-null   float64
#  14  SNAP_OAPP00              3143 non-null   int64
#  15  SNAP_OAPP05              3143 non-null   float64
#  16  SNAP_OAPP10              3143 non-null   float64
#  17  SNAP_FACEWAIVER00        3143 non-null   int64
#  18  SNAP_FACEWAIVER05        3143 non-null   float64
#  19  SNAP_FACEWAIVER10        3143 non-null   float64
#  20  SNAP_VEHEXCL00           3143 non-null   int64
#  21  SNAP_VEHEXCL05           3143 non-null   int64
#  22  SNAP_VEHEXCL10           3143 non-null   int64
#  23  SNAP_BBCE00              3143 non-null   int64
#  24  SNAP_BBCE05              3143 non-null   int64
#  25  SNAP_BBCE10              3143 non-null   int64
#  26  SNAP_REPORTSIMPLE00      3143 non-null   int64
#  27  SNAP_REPORTSIMPLE05      3143 non-null   int64
#  28  SNAP_REPORTSIMPLE10      3143 non-null   int64
#  29  PCT_NSLP09               3143 non-null   float64
#  30  PCT_NSLP14               3143 non-null   float64
#  31  PCH_NSLP_09_14           3143 non-null   float64
#  32  PCT_FREE_LUNCH06         3131 non-null   float64
#  33  PCT_FREE_LUNCH10         3125 non-null   float64
#  34  PCT_REDUCED_LUNCH06      3129 non-null   float64
#  35  PCT_REDUCED_LUNCH10      3125 non-null   float64
#  36  PCT_SBP09                3143 non-null   float64
#  37  PCT_SBP14                3143 non-null   float64
#  38  PCH_SBP_09_14            3143 non-null   float64
#  39  PCT_SFSP09               3143 non-null   float64
#  40  PCT_SFSP14               3143 non-null   float64
#  41  PCH_SFSP_09_14           3143 non-null   float64
#  42  PC_WIC_REDEMP08          2079 non-null   float64
#  43  PC_WIC_REDEMP12          2004 non-null   float64
#  44  PCH_PC_WIC_REDEMP_08_12  1942 non-null   float64
#  45  REDEMP_WICS08            2079 non-null   float64
#  46  REDEMP_WICS12            2004 non-null   float64
#  47  PCH_REDEMP_WICS_08_12    1942 non-null   float64
#  48  PCT_WIC09                3143 non-null   float64
#  49  PCT_WIC14                3143 non-null   float64
#  50  PCH_WIC_09_14            3143 non-null   float64
#  51  PCT_CACFP09              3143 non-null   float64
#  52  PCT_CACFP14              3143 non-null   float64
#  53  PCH_CACFP_09_14          3143 non-null   float64
#  54  FDPIR12                  3143 non-null   int64
# dtypes: float64(40), int64(13), object(2)
# memory usage: 1.3+ MB

# %%
# drop features that represent data for the years after 2010 (future data): 2012, 2014
# when there is data describing the same feature for several years keep the most recent (i.e. closest to 2010)
# caveat: for some features 2008 is the most recent year, but they have too many NULLs -> should be dropped
years = ['00','05','06','08','12','14']
cols=[col for col in assist.columns if any(year in col for year in years)]

assist.drop(cols, axis=1, inplace=True)

#drop [PC_SNAPBEN10] feature: too many NULLs
assist.drop('PC_SNAPBEN10',axis=1,inplace=True)


assist.drop('FIPS',axis=1).corr()
# Out:
#                      PCT_SNAP09  SNAP_PART_RATE10  SNAP_OAPP10  \
# PCT_SNAP09             1.000000          0.442471    -0.076608
# SNAP_PART_RATE10       0.442471          1.000000    -0.041883
# SNAP_OAPP10           -0.076608         -0.041883     1.000000
# SNAP_FACEWAIVER10     -0.089685          0.013088     0.334383
# SNAP_VEHEXCL10         0.074293          0.404915    -0.296011
# SNAP_BBCE10            0.261107          0.069584     0.071594
# SNAP_REPORTSIMPLE10    0.257202          0.391242    -0.039942
# PCT_NSLP09             0.266232         -0.153002    -0.017413
# PCT_FREE_LUNCH10       0.505366          0.014954    -0.064223
# PCT_REDUCED_LUNCH10   -0.169277         -0.066271    -0.077527
# PCT_SBP09              0.662447         -0.145525    -0.079137
# PCT_SFSP09             0.227641          0.069172    -0.157031
# PCT_WIC09              0.388665         -0.236744     0.081622
# PCT_CACFP09           -0.166974         -0.160700    -0.171798
#
#                      SNAP_FACEWAIVER10  SNAP_VEHEXCL10  SNAP_BBCE10  \
# PCT_SNAP09                   -0.089685        0.074293     0.261107
# SNAP_PART_RATE10              0.013088        0.404915     0.069584
# SNAP_OAPP10                   0.334383       -0.296011     0.071594
# SNAP_FACEWAIVER10             1.000000       -0.138392     0.008907
# SNAP_VEHEXCL10               -0.138392        1.000000    -0.019126
# SNAP_BBCE10                   0.008907       -0.019126     1.000000
# SNAP_REPORTSIMPLE10           0.125559       -0.057298    -0.003132
# PCT_NSLP09                    0.007302       -0.396336    -0.050625
# PCT_FREE_LUNCH10             -0.037258        0.007888     0.138381
# PCT_REDUCED_LUNCH10           0.019192       -0.055949    -0.197930
# PCT_SBP09                    -0.040565       -0.361470     0.225409
# PCT_SFSP09                    0.126068        0.034114     0.231744
# PCT_WIC09                     0.078320       -0.308232     0.303248
# PCT_CACFP09                  -0.131465       -0.254598    -0.072515
#
#                      SNAP_REPORTSIMPLE10  PCT_NSLP09  PCT_FREE_LUNCH10  \
# PCT_SNAP09                      0.257202    0.266232          0.505366
# SNAP_PART_RATE10                0.391242   -0.153002          0.014954
# SNAP_OAPP10                    -0.039942   -0.017413         -0.064223
# SNAP_FACEWAIVER10               0.125559    0.007302         -0.037258
# SNAP_VEHEXCL10                 -0.057298   -0.396336          0.007888
# SNAP_BBCE10                    -0.003132   -0.050625          0.138381
# SNAP_REPORTSIMPLE10             1.000000    0.174548          0.038801
# PCT_NSLP09                      0.174548    1.000000          0.234358
# PCT_FREE_LUNCH10                0.038801    0.234358          1.000000
# PCT_REDUCED_LUNCH10            -0.025649    0.145012         -0.096981
# PCT_SBP09                       0.108411    0.657394          0.547819
# PCT_SFSP09                      0.166496    0.065027          0.091470
# PCT_WIC09                      -0.114450    0.519073          0.441489
# PCT_CACFP09                     0.036900    0.503075         -0.062696
#
#                      PCT_REDUCED_LUNCH10  PCT_SBP09  PCT_SFSP09  PCT_WIC09  \
# PCT_SNAP09                     -0.169277   0.662447    0.227641   0.388665
# SNAP_PART_RATE10               -0.066271  -0.145525    0.069172  -0.236744
# SNAP_OAPP10                    -0.077527  -0.079137   -0.157031   0.081622
# SNAP_FACEWAIVER10               0.019192  -0.040565    0.126068   0.078320
# SNAP_VEHEXCL10                 -0.055949  -0.361470    0.034114  -0.308232
# SNAP_BBCE10                    -0.197930   0.225409    0.231744   0.303248
# SNAP_REPORTSIMPLE10            -0.025649   0.108411    0.166496  -0.114450
# PCT_NSLP09                      0.145012   0.657394    0.065027   0.519073
# PCT_FREE_LUNCH10               -0.096981   0.547819    0.091470   0.441489
# PCT_REDUCED_LUNCH10             1.000000  -0.042168   -0.048652  -0.026097
# PCT_SBP09                      -0.042168   1.000000    0.234924   0.787021
# PCT_SFSP09                     -0.048652   0.234924    1.000000   0.096594
# PCT_WIC09                      -0.026097   0.787021    0.096594   1.000000
# PCT_CACFP09                     0.234670   0.140728    0.035400   0.173655
#
#                      PCT_CACFP09
# PCT_SNAP09             -0.166974
# SNAP_PART_RATE10       -0.160700
# SNAP_OAPP10            -0.171798
# SNAP_FACEWAIVER10      -0.131465
# SNAP_VEHEXCL10         -0.254598
# SNAP_BBCE10            -0.072515
# SNAP_REPORTSIMPLE10     0.036900
# PCT_NSLP09              0.503075
# PCT_FREE_LUNCH10       -0.062696
# PCT_REDUCED_LUNCH10     0.234670
# PCT_SBP09               0.140728
# PCT_SFSP09              0.035400
# PCT_WIC09               0.173655
# PCT_CACFP09             1.000000

# %%
# State Food Insecurity
insecur = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='INSECURITY')
insecur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3256 entries, 0 to 3255
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FIPS                   3256 non-null   int64
#  1   State                  3256 non-null   object
#  2   County                 3256 non-null   object
#  3   FOODINSEC_00_02        3144 non-null   float64
#  4   FOODINSEC_07_09        3144 non-null   float64
#  5   FOODINSEC_10_12        3144 non-null   float64
#  6   CH_FOODINSEC_02_12     3144 non-null   float64
#  7   CH_FOODINSEC_09_12     3144 non-null   float64
#  8   VLFOODSEC_00_02        3144 non-null   float64
#  9   VLFOODSEC_07_09        3144 non-null   float64
#  10  VLFOODSEC_10_12        3144 non-null   float64
#  11  CH_VLFOODSEC_02_12     3144 non-null   float64
#  12  CH_VLFOODSEC_09_12     3144 non-null   float64
#  13  FOODINSEC_CHILD_01_07  3144 non-null   float64
#  14  FOODINSEC_CHILD_03_11  3144 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 381.7+ KB

# %%
# drop features that represent data for the years after 2010 (future data) 
# keep features from the most recent year when there is data for more than one year available
insecur=insecur[['FIPS','State','County','FOODINSEC_07_09','VLFOODSEC_07_09','FOODINSEC_CHILD_01_07']]

# %%
insecur.drop('FIPS',axis=1).corr()
# Out:
#                        FOODINSEC_07_09  VLFOODSEC_07_09  FOODINSEC_CHILD_01_07
# FOODINSEC_07_09               1.000000         0.892626               0.817430
# VLFOODSEC_07_09               0.892626         1.000000               0.650044
# FOODINSEC_CHILD_01_07         0.817430         0.650044               1.000000

# %% [markdown]
# All three features are highly correlated

# %%
# Food Prices and Taxes
prtax = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='PRICES_TAXES')
prtax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3256 entries, 0 to 3255
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FIPS               3256 non-null   int64
#  1   State              3256 non-null   object
#  2   County             3256 non-null   object
#  3   MILK_PRICE10       3110 non-null   float64
#  4   SODA_PRICE10       3110 non-null   float64
#  5   MILK_SODA_PRICE10  3110 non-null   float64
#  6   SODATAX_STORES11   3144 non-null   float64
#  7   SODATAX_VENDM11    3144 non-null   float64
#  8   CHIPSTAX_STORES11  3144 non-null   float64
#  9   CHIPSTAX_VENDM11   3144 non-null   float64
#  10  FOOD_TAX11         3144 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 279.9+ KB

# %%
# drop 2011 data
cols=[col for col in prtax.columns if '11' in col]
prtax.drop(cols,axis=1,inplace=True)

# %%
prtax.drop('FIPS',axis=1).corr()
# Out:
#                    MILK_PRICE10  SODA_PRICE10  MILK_SODA_PRICE10
# MILK_PRICE10           1.000000     -0.034412           0.916491
# SODA_PRICE10          -0.034412      1.000000          -0.425257
# MILK_SODA_PRICE10      0.916491     -0.425257           1.000000

# %% [markdown]
# [MILK_PRICE10] and [MILK_SODA_PRICE10] are highly correlated

# %%
# Local Foods
local = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='LOCAL')
local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255 entries, 0 to 3254
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   FIPS                  3255 non-null   int64
#  1   State                 3255 non-null   object
#  2   County                3255 non-null   object
#  3   DIRSALES_FARMS07      3078 non-null   float64
#  4   PCT_LOCLFARM07        3021 non-null   float64
#  5   PCT_LOCLSALE07        2750 non-null   float64
#  6   DIRSALES07            2852 non-null   float64
#  7   PC_DIRSALES07         2852 non-null   float64
#  8   FMRKT09               3141 non-null   float64
#  9   FMRKT13               3142 non-null   float64
#  10  PCH_FMRKT_09_13       2659 non-null   float64
#  11  FMRKTPTH09            3137 non-null   float64
#  12  FMRKTPTH13            3138 non-null   float64
#  13  PCH_FMRKTPTH_09_13    2655 non-null   float64
#  14  FMRKT_SNAP13          2181 non-null   float64
#  15  PCT_FMRKT_SNAP13      2181 non-null   float64
#  16  FMRKT_WIC13           2181 non-null   float64
#  17  PCT_FMRKT_WIC13       2181 non-null   float64
#  18  FMRKT_WICCASH13       2181 non-null   float64
#  19  PCT_FMRKT_WICCASH13   2181 non-null   float64
#  20  FMRKT_SFMNP13         2181 non-null   float64
#  21  PCT_FMRKT_SFMNP13     2181 non-null   float64
#  22  FMRKT_FRVEG13         2181 non-null   float64
#  23  PCT_FRMKT_FRVEG13     2181 non-null   float64
#  24  FMRKT_ANMLPROD13      2181 non-null   float64
#  25  PCT_FRMKT_ANMLPROD13  2181 non-null   float64
#  26  FMRKT_OTHER13         2181 non-null   float64
#  27  PCT_FMRKT_OTHER13     2181 non-null   float64
#  28  VEG_FARMS07           3077 non-null   float64
#  29  VEG_ACRES07           2530 non-null   float64
#  30  VEG_ACRESPTH07        2529 non-null   float64
#  31  FRESHVEG_FARMS07      3077 non-null   float64
#  32  FRESHVEG_ACRES07      1840 non-null   float64
#  33  FRESHVEG_ACRESPTH07   1840 non-null   float64
#  34  ORCHARD_FARMS07       3077 non-null   float64
#  35  ORCHARD_ACRES07       2592 non-null   float64
#  36  ORCHARD_ACRESPTH07    2592 non-null   float64
#  37  BERRY_FARMS07         3077 non-null   float64
#  38  BERRY_ACRES07         2302 non-null   float64
#  39  BERRY_ACRESPTH07      2302 non-null   float64
#  40  SLHOUSE07             3142 non-null   float64
#  41  GHVEG_FARMS07         3077 non-null   float64
#  42  GHVEG_SQFT07          2297 non-null   float64
#  43  GHVEG_SQFTPTH07       2297 non-null   float64
#  44  FOODHUB12             3142 non-null   float64
#  45  CSA07                 3142 non-null   float64
#  46  AGRITRSM_OPS07        3142 non-null   float64
#  47  AGRITRSM_RCT07        1521 non-null   float64
#  48  FARM_TO_SCHOOL        3142 non-null   float64
# dtypes: float64(46), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
# drop features that represent data for 2013
cols=[col for col in local.columns if '13' in col]
local.drop(cols, axis=1, inplace=True)

#drop features represented in count/acres when there is feature represetned in count/acres per 1,000pop
#drop 2012 feature
abs_feat=['DIRSALES_FARMS07','FMRKT09','VEG_ACRES07','FRESHVEG_ACRES07','ORCHARD_ACRES07',
          'BERRY_ACRES07','GHVEG_SQFT07','FOODHUB12']
local.drop(abs_feat,axis=1,inplace=True)


local.drop('FIPS',axis=1).corr()
# Out:
#                      PCT_LOCLFARM07  PCT_LOCLSALE07  DIRSALES07  \
# PCT_LOCLFARM07             1.000000        0.670449    0.381677
# PCT_LOCLSALE07             0.670449        1.000000    0.337164
# DIRSALES07                 0.381677        0.337164    1.000000
# PC_DIRSALES07              0.124463        0.136284    0.261886
# FMRKTPTH09                 0.004992       -0.005760   -0.033787
# VEG_FARMS07                0.262089        0.146442    0.516805
# VEG_ACRESPTH07            -0.047904       -0.068822    0.013322
# FRESHVEG_FARMS07           0.269351        0.166148    0.495724
# FRESHVEG_ACRESPTH07       -0.035209       -0.054540    0.030027
# ORCHARD_FARMS07            0.078640        0.014399    0.592419
# ORCHARD_ACRESPTH07        -0.023355       -0.043761    0.132257
# BERRY_FARMS07              0.370002        0.207939    0.500761
# BERRY_ACRESPTH07           0.064312       -0.008979    0.025089
# SLHOUSE07                  0.112774        0.011668    0.234153
# GHVEG_FARMS07              0.374543        0.278309    0.499132
# GHVEG_SQFTPTH07            0.077988        0.053649    0.087837
# CSA07                      0.266313        0.169872    0.626719
# AGRITRSM_OPS07             0.006311        0.032102    0.185543
# AGRITRSM_RCT07             0.091958        0.081305    0.216697
# FARM_TO_SCHOOL             0.243272        0.232568    0.249366
#
#                      PC_DIRSALES07  FMRKTPTH09  VEG_FARMS07  VEG_ACRESPTH07  \
# PCT_LOCLFARM07            0.124463    0.004992     0.262089       -0.047904
# PCT_LOCLSALE07            0.136284   -0.005760     0.146442       -0.068822
# DIRSALES07                0.261886   -0.033787     0.516805        0.013322
# PC_DIRSALES07             1.000000    0.125808     0.072476        0.094091
# FMRKTPTH09                0.125808    1.000000    -0.042487        0.008844
# VEG_FARMS07               0.072476   -0.042487     1.000000        0.117964
# VEG_ACRESPTH07            0.094091    0.008844     0.117964        1.000000
# FRESHVEG_FARMS07          0.060610   -0.039198     0.974732        0.046536
# FRESHVEG_ACRESPTH07       0.067212    0.004728     0.105208        0.737637
# ORCHARD_FARMS07           0.064056   -0.028748     0.352299        0.011413
# ORCHARD_ACRESPTH07        0.143934   -0.050095     0.040302        0.102634
# BERRY_FARMS07             0.105293   -0.010042     0.408952       -0.024128
# BERRY_ACRESPTH07          0.024121    0.033414     0.017352        0.003424
# SLHOUSE07                -0.002241   -0.039340     0.190314       -0.008676
# GHVEG_FARMS07             0.125949    0.025111     0.482611       -0.037692
# GHVEG_SQFTPTH07           0.133890    0.032147     0.086533        0.010156
# CSA07                     0.145156    0.000109     0.470681       -0.013331
# AGRITRSM_OPS07            0.149250   -0.059115     0.144858       -0.028437
# AGRITRSM_RCT07            0.108711   -0.017453     0.171607        0.007186
# FARM_TO_SCHOOL            0.056194    0.019387     0.167775       -0.022631
#
#                      FRESHVEG_FARMS07  FRESHVEG_ACRESPTH07  ORCHARD_FARMS07  \
# PCT_LOCLFARM07               0.269351            -0.035209         0.078640
# PCT_LOCLSALE07               0.166148            -0.054540         0.014399
# DIRSALES07                   0.495724             0.030027         0.592419
# PC_DIRSALES07                0.060610             0.067212         0.064056
# FMRKTPTH09                  -0.039198             0.004728        -0.028748
# VEG_FARMS07                  0.974732             0.105208         0.352299
# VEG_ACRESPTH07               0.046536             0.737637         0.011413
# FRESHVEG_FARMS07             1.000000             0.088024         0.333241
# FRESHVEG_ACRESPTH07          0.088024             1.000000         0.026878
# ORCHARD_FARMS07              0.333241             0.026878         1.000000
# ORCHARD_ACRESPTH07           0.025902             0.084495         0.280116
# BERRY_FARMS07                0.410952            -0.001769         0.206232
# BERRY_ACRESPTH07             0.018167             0.001021         0.005566
# SLHOUSE07                    0.176871            -0.019910         0.150125
# GHVEG_FARMS07                0.496975            -0.019168         0.277792
# GHVEG_SQFTPTH07              0.090985             0.022159         0.018534
# CSA07                        0.457281             0.014060         0.584106
# AGRITRSM_OPS07               0.154788            -0.004360         0.136034
# AGRITRSM_RCT07               0.177054             0.041020         0.189031
# FARM_TO_SCHOOL               0.171747            -0.003561         0.140695
#
#                      ORCHARD_ACRESPTH07  BERRY_FARMS07  BERRY_ACRESPTH07  \
# PCT_LOCLFARM07                -0.023355       0.370002          0.064312
# PCT_LOCLSALE07                -0.043761       0.207939         -0.008979
# DIRSALES07                     0.132257       0.500761          0.025089
# PC_DIRSALES07                  0.143934       0.105293          0.024121
# FMRKTPTH09                    -0.050095      -0.010042          0.033414
# VEG_FARMS07                    0.040302       0.408952          0.017352
# VEG_ACRESPTH07                 0.102634      -0.024128          0.003424
# FRESHVEG_FARMS07               0.025902       0.410952          0.018167
# FRESHVEG_ACRESPTH07            0.084495      -0.001769          0.001021
# ORCHARD_FARMS07                0.280116       0.206232          0.005566
# ORCHARD_ACRESPTH07             1.000000       0.014129          0.004513
# BERRY_FARMS07                  0.014129       1.000000          0.402431
# BERRY_ACRESPTH07               0.004513       0.402431          1.000000
# SLHOUSE07                     -0.002174       0.121761         -0.010596
# GHVEG_FARMS07                 -0.000133       0.499578          0.034897
# GHVEG_SQFTPTH07                0.002086       0.119496          0.037585
# CSA07                          0.106318       0.442474          0.032932
# AGRITRSM_OPS07                 0.130487       0.124645         -0.020179
# AGRITRSM_RCT07                 0.097291       0.093954         -0.017816
# FARM_TO_SCHOOL                 0.035906       0.184388          0.079099
#
#                      SLHOUSE07  GHVEG_FARMS07  GHVEG_SQFTPTH07     CSA07  \
# PCT_LOCLFARM07        0.112774       0.374543         0.077988  0.266313
# PCT_LOCLSALE07        0.011668       0.278309         0.053649  0.169872
# DIRSALES07            0.234153       0.499132         0.087837  0.626719
# PC_DIRSALES07        -0.002241       0.125949         0.133890  0.145156
# FMRKTPTH09           -0.039340       0.025111         0.032147  0.000109
# VEG_FARMS07           0.190314       0.482611         0.086533  0.470681
# VEG_ACRESPTH07       -0.008676      -0.037692         0.010156 -0.013331
# FRESHVEG_FARMS07      0.176871       0.496975         0.090985  0.457281
# FRESHVEG_ACRESPTH07  -0.019910      -0.019168         0.022159  0.014060
# ORCHARD_FARMS07       0.150125       0.277792         0.018534  0.584106
# ORCHARD_ACRESPTH07   -0.002174      -0.000133         0.002086  0.106318
# BERRY_FARMS07         0.121761       0.499578         0.119496  0.442474
# BERRY_ACRESPTH07     -0.010596       0.034897         0.037585  0.032932
# SLHOUSE07             1.000000       0.186216         0.031412  0.199313
# GHVEG_FARMS07         0.186216       1.000000         0.308269  0.525462
# GHVEG_SQFTPTH07       0.031412       0.308269         1.000000  0.121864
# CSA07                 0.199313       0.525462         0.121864  1.000000
# AGRITRSM_OPS07        0.091782       0.170969        -0.007345  0.221868
# AGRITRSM_RCT07        0.120528       0.191746         0.067270  0.281922
# FARM_TO_SCHOOL        0.162085       0.228004         0.033258  0.222025
#
#                      AGRITRSM_OPS07  AGRITRSM_RCT07  FARM_TO_SCHOOL
# PCT_LOCLFARM07             0.006311        0.091958        0.243272
# PCT_LOCLSALE07             0.032102        0.081305        0.232568
# DIRSALES07                 0.185543        0.216697        0.249366
# PC_DIRSALES07              0.149250        0.108711        0.056194
# FMRKTPTH09                -0.059115       -0.017453        0.019387
# VEG_FARMS07                0.144858        0.171607        0.167775
# VEG_ACRESPTH07            -0.028437        0.007186       -0.022631
# FRESHVEG_FARMS07           0.154788        0.177054        0.171747
# FRESHVEG_ACRESPTH07       -0.004360        0.041020       -0.003561
# ORCHARD_FARMS07            0.136034        0.189031        0.140695
# ORCHARD_ACRESPTH07         0.130487        0.097291        0.035906
# BERRY_FARMS07              0.124645        0.093954        0.184388
# BERRY_ACRESPTH07          -0.020179       -0.017816        0.079099
# SLHOUSE07                  0.091782        0.120528        0.162085
# GHVEG_FARMS07              0.170969        0.191746        0.228004
# GHVEG_SQFTPTH07           -0.007345        0.067270        0.033258
# CSA07                      0.221868        0.281922        0.222025
# AGRITRSM_OPS07             1.000000        0.546050        0.045155
# AGRITRSM_RCT07             0.546050        1.000000        0.078584
# FARM_TO_SCHOOL             0.045155        0.078584        1.000000

# %%
# drop features with over 255 NULLs
local.dropna(thresh=3000,axis=1,inplace=True)
local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3255 entries, 0 to 3254
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FIPS              3255 non-null   int64
#  1   State             3255 non-null   object
#  2   County            3255 non-null   object
#  3   PCT_LOCLFARM07    3021 non-null   float64
#  4   FMRKTPTH09        3137 non-null   float64
#  5   VEG_FARMS07       3077 non-null   float64
#  6   FRESHVEG_FARMS07  3077 non-null   float64
#  7   ORCHARD_FARMS07   3077 non-null   float64
#  8   BERRY_FARMS07     3077 non-null   float64
#  9   SLHOUSE07         3142 non-null   float64
#  10  GHVEG_FARMS07     3077 non-null   float64
#  11  CSA07             3142 non-null   float64
#  12  AGRITRSM_OPS07    3142 non-null   float64
#  13  FARM_TO_SCHOOL    3142 non-null   float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 356.1+ KB

# %%
# Socioeconomic Characteristics
secon = pd.read_excel('FoodAvailabilityDataset.xls',sheet_name='SOCIOECONOMIC')
secon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FIPS             3143 non-null   int64
#  1   State            3143 non-null   object
#  2   County           3143 non-null   object
#  3   PCT_NHWHITE10    3143 non-null   float64
#  4   PCT_NHBLACK10    3143 non-null   float64
#  5   PCT_HISP10       3143 non-null   float64
#  6   PCT_NHASIAN10    3143 non-null   float64
#  7   PCT_NHNA10       3143 non-null   float64
#  8   PCT_NHPI10       3143 non-null   float64
#  9   PCT_65OLDER10    3143 non-null   float64
#  10  PCT_18YOUNGER10  3143 non-null   float64
#  11  MEDHHINC10       3143 non-null   object
#  12  POVRATE10        3143 non-null   object
#  13  PERPOV10         3143 non-null   int64
#  14  CHILDPOVRATE10   3143 non-null   object
#  15  PERCHLDPOV10     3143 non-null   int64
#  16  METRO13          3143 non-null   int64
#  17  POPLOSS00        3143 non-null   object
# dtypes: float64(8), int64(4), object(6)
# memory usage: 442.1+ KB

# %%
# create a list of dataframes
dfs = [access,stores,rstrnt,assist,insecur,prtax,local,health,secon,obesity]
from functools import reduce

#append dataframes into one
data = reduce(lambda left,right: pd.merge(left,right), dfs)

# %%
data.index=data.FIPS

# %%
data.drop('FIPS',axis=1,inplace=True)
data.head()
# Out:
#      State   County  PCT_LACCESS_POP10  PCT_LACCESS_LOWI10  \
# FIPS
# 1001    AL  Autauga          33.769657            9.793530
# 1003    AL  Baldwin          19.318473            5.460261
# 1005    AL  Barbour          20.840972           11.420316
# 1007    AL     Bibb           4.559753            2.144661
# 1009    AL   Blount           2.700840            1.062468
#
#       PCT_LACCESS_CHILD10  PCT_LACCESS_SENIORS10  PCT_LACCESS_HHNV10  \
# FIPS
# 1001             8.837112               4.376378            3.284786
# 1003             4.343199               3.513570            2.147827
# 1005             3.425062               2.805166            4.135869
# 1007             1.087518               0.657008            3.458580
# 1009             0.671490               0.340269            3.269380
#
#       GROCPTH07  SUPERCPTH07  CONVSPTH07  ...  PCT_65OLDER10  PCT_18YOUNGER10  \
# FIPS                                      ...
# 1001   0.080266     0.020067    0.742465  ...      11.995382        26.777959
# 1003   0.133090     0.017360    1.093655  ...      16.771185        22.987408
# 1005   0.201776     0.000000    0.437181  ...      14.236807        21.906982
# 1007   0.325809     0.000000    0.372353  ...      12.681650        22.696923
# 1009   0.105511     0.017585    0.263778  ...      14.722096        24.608353
#
#       MEDHHINC10  POVRATE10  PERPOV10  CHILDPOVRATE10  PERCHLDPOV10  METRO13  \
# FIPS
# 1001       53049       11.9         0            17.5             0        1
# 1003       47618       13.3         0            20.2             0        1
# 1005       33074       25.3         1            36.2             1        0
# 1007       35472       20.9         0            28.6             1        1
# 1009       42906       16.5         0            24.1             0        1
#
#       POPLOSS00  PCT_OBESE_ADULTS10
# FIPS
# 1001          0                30.5
# 1003          0                26.6
# 1005          0                37.3
# 1007          0                34.3
# 1009          0                30.4
#
# [5 rows x 66 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3150 entries, 1001 to 56045
# Data columns (total 66 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State                  3150 non-null   object
#  1   County                 3150 non-null   object
#  2   PCT_LACCESS_POP10      3150 non-null   float64
#  3   PCT_LACCESS_LOWI10     3150 non-null   float64
#  4   PCT_LACCESS_CHILD10    3150 non-null   float64
#  5   PCT_LACCESS_SENIORS10  3150 non-null   float64
#  6   PCT_LACCESS_HHNV10     3150 non-null   float64
#  7   GROCPTH07              3150 non-null   float64
#  8   SUPERCPTH07            3150 non-null   float64
#  9   CONVSPTH07             3150 non-null   float64
#  10  SPECSPTH07             3150 non-null   float64
#  11  SNAPSPTH08             3150 non-null   float64
#  12  WICSPTH08              3150 non-null   float64
#  13  FFRPTH07               3145 non-null   float64
#  14  FSRPTH07               3145 non-null   float64
#  15  PC_FFRSALES07          3150 non-null   float64
#  16  PC_FSRSALES07          3150 non-null   float64
#  17  PCT_SNAP09             3150 non-null   float64
#  18  SNAP_PART_RATE10       3150 non-null   float64
#  19  SNAP_OAPP10            3150 non-null   float64
#  20  SNAP_FACEWAIVER10      3150 non-null   float64
#  21  SNAP_VEHEXCL10         3150 non-null   int64
#  22  SNAP_BBCE10            3150 non-null   int64
#  23  SNAP_REPORTSIMPLE10    3150 non-null   int64
#  24  PCT_NSLP09             3150 non-null   float64
#  25  PCT_FREE_LUNCH10       3132 non-null   float64
#  26  PCT_REDUCED_LUNCH10    3132 non-null   float64
#  27  PCT_SBP09              3150 non-null   float64
#  28  PCT_SFSP09             3150 non-null   float64
#  29  PCT_WIC09              3150 non-null   float64
#  30  PCT_CACFP09            3150 non-null   float64
#  31  FOODINSEC_07_09        3150 non-null   float64
#  32  VLFOODSEC_07_09        3150 non-null   float64
#  33  FOODINSEC_CHILD_01_07  3150 non-null   float64
#  34  MILK_PRICE10           3116 non-null   float64
#  35  SODA_PRICE10           3116 non-null   float64
#  36  MILK_SODA_PRICE10      3116 non-null   float64
#  37  PCT_LOCLFARM07         3028 non-null   float64
#  38  FMRKTPTH09             3137 non-null   float64
#  39  VEG_FARMS07            3077 non-null   float64
#  40  FRESHVEG_FARMS07       3077 non-null   float64
#  41  ORCHARD_FARMS07        3077 non-null   float64
#  42  BERRY_FARMS07          3077 non-null   float64
#  43  SLHOUSE07              3145 non-null   float64
#  44  GHVEG_FARMS07          3077 non-null   float64
#  45  CSA07                  3145 non-null   float64
#  46  AGRITRSM_OPS07         3145 non-null   float64
#  47  FARM_TO_SCHOOL         3145 non-null   float64
#  48  RECFACPTH07            3145 non-null   float64
#  49  NATAMEN                3108 non-null   float64
#  50  PCT_NHWHITE10          3150 non-null   float64
#  51  PCT_NHBLACK10          3150 non-null   float64
#  52  PCT_HISP10             3150 non-null   float64
#  53  PCT_NHASIAN10          3150 non-null   float64
#  54  PCT_NHNA10             3150 non-null   float64
#  55  PCT_NHPI10             3150 non-null   float64
#  56  PCT_65OLDER10          3150 non-null   float64
#  57  PCT_18YOUNGER10        3150 non-null   float64
#  58  MEDHHINC10             3150 non-null   object
#  59  POVRATE10              3150 non-null   object
#  60  PERPOV10               3150 non-null   int64
#  61  CHILDPOVRATE10         3150 non-null   object
#  62  PERCHLDPOV10           3150 non-null   int64
#  63  METRO13                3150 non-null   int64
#  64  POPLOSS00              3150 non-null   object
#  65  PCT_OBESE_ADULTS10     3145 non-null   float64
# dtypes: float64(54), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
#remove duplicate rows
data.drop_duplicates(inplace=True)
len(data)
# Out:
# 3143

# %%
data.to_csv('food_atlas_combined.csv')
